# %%
# Per migliorare la qualità del dataset, rielaboro la feature "categories", inizialmente poco informativa
# Attraverso l'uso di modelli LLM, applico una tecnica di text classification per assegnare a ciascun libro una categoria coerente
# Questa nuova classificazione verrà utilizzata dall'utente come filtro durante la ricerca dei titoli

# La text classification è una tecnica di NLP che consente di associare testi a classi discrete
# In questo caso, le categorie di interesse sono: Fiction, Nonfiction (+ Juvenile Fiction e Juvenile Nonfiction)
# Esistono molte tecniche per classificare il testo, ma l'uso di LLM preaddestrati garantisce ottimi risultati

# In particolare, utilizzo la strategia di zero-shot classification
# Consente di classificare testi in categorie mai viste esplicitamente durante il training, grazie alle conoscenze apprese dal modello
# Si utilizza un modello preaddestrato che prende un testo e un insieme di etichette candidate (es. Fiction, Nonfiction)
# Produce un punteggio di similarità tra il testo e ciascuna etichetta
# L'etichetta con il punteggio più alto viene assegnata al testo

# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# %%
print(books["categories"].nunique())
print(books["categories"].value_counts())
# Out:
# 464
# categories
# Fiction                      2062
# Juvenile Fiction              383
# Biography & Autobiography     310
# History                       205
# Literary Criticism            123
#                              ...
# Rock musicians                  1
# Community life                  1
# Air pilots                      1
# Authors, Canadian               1
# Indic fiction (English)         1
# Name: count, Length: 464, dtype: int64

# %%
# Guardo le categorie che hanno 25 libri associati o più
books["categories"].value_counts().reset_index().query("count >= 25")
# Out:
#                    categories  count
# 0                     Fiction   2062
# 1            Juvenile Fiction    383
# 2   Biography & Autobiography    310
# 3                     History    205
# 4          Literary Criticism    123
# 5                  Philosophy    117
# 6                    Religion    117
# 7     Comics & Graphic Novels    114
# 8                       Drama     81
# 9         Juvenile Nonfiction     56
# 10                    Science     53
# 11       Literary Collections     50
# 12                     Poetry     49
# 13       Business & Economics     49
# 14             Social Science     47
# 15            Performing Arts     40
# 16                    Cooking     35
# 17                 Psychology     33
# 18                     Travel     32
# 19        Body, Mind & Spirit     32
# 20                        Art     32
# 21          Political Science     30
# 22                  Computers     28
# 23           Health & Fitness     28
# 24                  Self-Help     28
# 25     Family & Relationships     27

# %%
# La categoria "Juvenile Fiction" sembra rappresenti libri di Fiction per bambini
books[books["categories"] == "Juvenile Fiction"]
# Out:
#              isbn13      isbn10  \
# 30    9780006646006  000664600X
# 77    9780020442608  0020442602
# 83    9780030547744  0030547741
# 84    9780060000141  0060000147
# 85    9780060001537  0060001534
# ...             ...         ...
# 4750  9781590385814  1590385810
# 4830  9781596792500  1596792507
# 4842  9781599900056  159990005X
# 4907  9781844580514  1844580512
# 5051  9781932416374  1932416374
#
#                                                   title  \
# 30                                   Ocean Star Express
# 77                       The voyage of the Dawn Treader
# 83                             Where the Red Fern Grows
# 84                                       Poppy's Return
# 85                                    Diary of a Spider
# ...                                                 ...
# 4750                                         Fablehaven
# 4830  Sherlock Holmes and the Case of the Hound of t...
# 4842                                    The Drift House
# 4907                               Attack of the Jaguar
# 5051                The Very Persistent Gappers of Frip
#
#                                   authors        categories  \
# 30               Mark Haddon;Peter Sutton  Juvenile Fiction
# 77                    Clive Staples Lewis  Juvenile Fiction
# 83                           Wilson Rawls  Juvenile Fiction
# 84                                    Avi  Juvenile Fiction
# 85                          Doreen Cronin  Juvenile Fiction
# ...                                   ...               ...
# 4750                         Brandon Mull  Juvenile Fiction
# 4830  Arthur Conan Doyle;Malvina G. Vogel  Juvenile Fiction
# 4842                            Dale Peck  Juvenile Fiction
# 4907                         M. A. Harvey  Juvenile Fiction
# 5051           George Saunders;Lane Smith  Juvenile Fiction
#
#                                               thumbnail  \
# 30    http://books.google.com/books/content?id=I2QZA...
# 77    http://books.google.com/books/content?id=fDD3C...
# 83    http://books.google.com/books/content?id=IHpRw...
# 84    http://books.google.com/books/content?id=XbcMJ...
# 85    http://books.google.com/books/content?id=UWvZo...
# ...                                                 ...
# 4750  http://books.google.com/books/content?id=tbVIP...
# 4830  http://books.google.com/books/content?id=EWgWP...
# 4842  http://books.google.com/books/content?id=kbwPY...
# 4907  http://books.google.com/books/content?id=3HUdt...
# 5051  http://books.google.com/books/content?id=xYJOP...
#
#                                             description  published_year  \
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 77    The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 83    A young boy living in the Ozarks achieves his ...          2000.0
# 84    There's trouble at Gray House, the girlhood ho...          2006.0
# 85    This is the diary ... of a spider. But don't b...          2005.0
# ...                                                 ...             ...
# 4750  When Kendra and Seth go to stay at their grand...          2006.0
# 4830  Sherlock Holmes and Dr. Watson travel to the b...          2005.0
# 4842  Sent to stay with their uncle in a ship-like h...          2006.0
# 4907  This training manual for operatives of Xtreme ...          2004.0
# 5051  A novel set in the seaside village of Frip fol...          2006.0
#
#       average_rating  num_pages  ratings_count  \
# 30              3.50       32.0            1.0
# 77              4.09      216.0         2869.0
# 83              4.37      288.0           95.0
# 84              3.99      256.0         1086.0
# 85              4.25       40.0         7903.0
# ...              ...        ...            ...
# 4750            4.09      351.0       111896.0
# 4830            4.51      237.0           28.0
# 4842            3.64      437.0          595.0
# 4907            3.40      125.0            4.0
# 5051            4.11       84.0         2317.0
#
#                                      title_and_subtitle  \
# 30                                   Ocean Star Express
# 77                       The voyage of the Dawn Treader
# 83    Where the Red Fern Grows: The Story of Two Dog...
# 84                                       Poppy's Return
# 85                                    Diary of a Spider
# ...                                                 ...
# 4750                                         Fablehaven
# 4830  Sherlock Holmes and the Case of the Hound of t...
# 4842                  The Drift House: The First Voyage
# 4907                               Attack of the Jaguar
# 5051                The Very Persistent Gappers of Frip
#
#                                      tagged_description
# 30    9780006646006: Joe and his parents are enjoyin...
# 77    9780020442608: The "Dawn Treader" is the first...
# 83    9780030547744: A young boy living in the Ozark...
# 84    9780060000141: There's trouble at Gray House, ...
# 85    9780060001537: This is the diary ... of a spid...
# ...                                                 ...
# 4750  9781590385814: When Kendra and Seth go to stay...
# 4830  9781596792500: Sherlock Holmes and Dr. Watson ...
# 4842  9781599900056: Sent to stay with their uncle i...
# 4907  9781844580514: This training manual for operat...
# 5051  9781932416374: A novel set in the seaside vill...
#
# [383 rows x 13 columns]

# 1730  9780380732548: From July 1942 until August 194...
# 1929  9780395776087: Recreates the devastation rende...
# 2060  9780439314558: From her birth in Chipping Sodb...
# 2072  9780439420068: A group of babies enjoys some f...
# 2094  9780439736466: A collection of poems, stories,...
# 2138  9780440229353: Author Gary Paulsen relates tal...
# 2164  9780440419174: Profiles the turbulent life of ...
# 2273  9780448437439: Chronicles the life of the pres...
# 2276  9780448444826: Looks closely at Anne Frank's l...
# 2449  9780486276809: Ten-year-old Mary comes to live...
# 2455  9780486296388: Forty-two clear, accurate drawi...
# 2557  9780525469780: Examines what is known about di...
# 2794  9780590032490: A young boy and his Norwegian g...
# 2795  9780590103879: A Down-to-Earth Approach James ...
# 2831  9780618111206: With powerful and rare photos b...
# 3061  9780679890522: In 1838, settlers moving west f...
# 3128  9780689833762: Knock, knock. Who's there? Some...
# 3129  9780689834196: Young Michael Jordan, who is sm...
# 3130  9780689835612: Is Mommy behind the chair? Is M...
# 3145  9780689869907: In this story based on a case f...
# 3149  9780689876707: PopTV is going to follow Star a...
# 3189  9780723247791: This original, authorised versi...
# 3196  9780736805995: Excerpts from the girlhood diar...
# 3217  9780739844328: Presents the life of Bill Gates...
# 3441  9780753459645: What is a leap year? Why are be...
# 3471  9780756614195: Glorious full-color illustratio...
# 3484  9780761417101: Looks at the events leading up ...
# 3715  9780789458209: Photographs and text explore th...
# 3716  9780791070482: Presents a collection of critic...
# 3717  9780791081266: One of Edith Wharton's most cri...
# 3718  9780792241737: Offers the true account of two ...
# 3779  9780805069853: An introduction to Robert Frost...
# 3781  9780805071061: Provides the story of the black...
# 3837  9780810935204: Lewis Carroll's classic and inv...
# 3985  9780822560562: Chronicles the life and career ...
# 3988  9780823410781: Traces the life of the young Je...
# 4319  9781400307845: Using selections from her works...
# 4502  9781560067849: Discusses the young adult book ...
# 4649  9781580495868: As he faces battle in the Civil...
# 4713  9781586853334: There's this boy. Let's say he'...
# 4937  9781857232097: The fifth book in Robert Jordan...
# 5036  9781931414166: Describes the construction of t...

# %%
# Mappo i generi trovati sopra nelle categorie Fiction o NonFiction
# Queste sembrano categorie di libri più interessanti, che possano guidare l'utente ad una scelta più mirata delle letture cercate

category_mapping = {
	"Fiction": 						"Fiction",
	"Juvenile Fiction": 			"Children's Fiction",
	"Biography & Autobiography":	"Nonfiction",
	"History": 						"Nonfiction",
	"Literary Criticism": 			"Nonfiction",
	"Philosophy": 					"Nonfiction",
	"Religion":						"Nonfiction",
	"Comics & Graphic Novels": 		"Fiction",
	"Drama": 						"Fiction",
	"Juvenile Nonfiction": 			"Children's Nonfiction",
	"Science": 						"Nonfiction",
	"Literary Collections": 		"Fiction",
	"Poetry": 						"Fiction",
	"Business & Economics": 		"Nonfiction",
	"Social Science": 				"Nonfiction",
	"Performing Arts": 				"Nonfiction",
	"Cooking": 						"Nonfiction",
	"Psychology": 					"Nonfiction",
	"Travel": 						"Nonfiction",
	"Body, Mind & Spirit": 			"Nonfiction",
	"Art": 							"Nonfiction",
	"Political Science": 			"Nonfiction",
	"Computers": 					"Nonfiction",
	"Health & Fitness": 			"Nonfiction",
	"Self-Help": 					"Nonfiction",
	"Family & Relationships": 		"Nonfiction"
}

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5084  9788172235222  8172235224
# 5085  9788173031014  8173031010
# 5086  9788179921623  817992162X
# 5087  9788185300535  8185300534
# 5088  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5084                                  Mistaken Identity
# 5085                                Journey to the East
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# 5087                                          I Am that
# 5088                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5084                              Nayantara Sahgal
# 5085                                 Hermann Hesse
# 5086                                  Robin Sharma
# 5087  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5088                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5084        Indic fiction (English)
# 5085              Adventure stories
# 5086               Health & Fitness
# 5087                     Philosophy
# 5088                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5084  http://books.google.com/books/content?id=q-tKP...
# 5085  http://books.google.com/books/content?id=rq6JP...
# 5086  http://books.google.com/books/content?id=c_7mf...
# 5087  http://books.google.com/books/content?id=Fv_JP...
# 5088  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5084  On A Train Journey Home To North India After L...          2003.0
# 5085  This book tells the tale of a man who goes on ...          2002.0
# 5086  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5087  This collection of the timeless teachings of o...          1999.0
# 5088  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5084            2.93      324.0            0.0
# 5085            3.70      175.0           24.0
# 5086            3.82      198.0         1568.0
# 5087            4.51      531.0          104.0
# 5088            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5084                                  Mistaken Identity
# 5085                                Journey to the East
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# 5087     I Am that: Talks with Sri Nisargadatta Maharaj
# 5088                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883: A NOVEL THAT READERS and critic...           Fiction
# 1     9780002261982: A new 'Christie for Christmas' ...               NaN
# 2     9780006178736: A memorable, mesmerizing heroin...           Fiction
# 3     9780006280897: Lewis' work on the nature of lo...               NaN
# 4     9780006280934: "In The Problem of Pain, C.S. L...               NaN
# ...                                                 ...               ...
# 5084  9788172235222: On A Train Journey Home To Nort...               NaN
# 5085  9788173031014: This book tells the tale of a m...               NaN
# 5086  9788179921623: Wisdom to Create a Life of Pass...        Nonfiction
# 5087  9788185300535: This collection of the timeless...        Nonfiction
# 5088  9789027712059: Since the three volume edition ...        Nonfiction
#
# [5089 rows x 14 columns]

# %%
books[~books["simple_categories"].isna()]

# Libri catalogati secondo questa nuova feature sono 4161/5089 (ne rimangono ancora non catalogati secondo Fiction o NonFiction)
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 2     9780006178736  0006178731
# 8     9780006482079  0006482074
# 30    9780006646006  000664600X
# 31    9780007105045  0007105045
# ...             ...         ...
# 5080  9784770028969  4770028962
# 5081  9788122200850  8122200850
# 5086  9788179921623  817992162X
# 5087  9788185300535  8185300534
# 5088  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 2                                        Rage of angels
# 8                                   Warhost of Vastmark
# 30                                   Ocean Star Express
# 31                                        Tree and Leaf
# ...                                                 ...
# 5080                                 Coin Locker Babies
# 5081                                   Cry, the Peacock
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# 5087                                          I Am that
# 5088                           The Berlin Phenomenology
#
#                                            authors            categories  \
# 0                               Marilynne Robinson               Fiction
# 2                                   Sidney Sheldon               Fiction
# 8                                      Janny Wurts               Fiction
# 30                        Mark Haddon;Peter Sutton      Juvenile Fiction
# 31                       John Ronald Reuel Tolkien  Literary Collections
# ...                                            ...                   ...
# 5080                                           村上龍               Fiction
# 5081                                   Anita Desai               Fiction
# 5086                                  Robin Sharma      Health & Fitness
# 5087  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit            Philosophy
# 5088                 Georg Wilhelm Friedrich Hegel               History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 8     http://books.google.com/books/content?id=uOL0f...
# 30    http://books.google.com/books/content?id=I2QZA...
# 31    http://books.google.com/books/content?id=aPb_A...
# ...                                                 ...
# 5080  http://books.google.com/books/content?id=87DJw...
# 5081  http://books.google.com/books/content?id=_QKwV...
# 5086  http://books.google.com/books/content?id=c_7mf...
# 5087  http://books.google.com/books/content?id=Fv_JP...
# 5088  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 8     Tricked once more by his wily half-brother, Ly...          1995.0
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 31    "The two works 'On fairy-stories' and 'Leaf by...          2001.0
# ...                                                 ...             ...
# 5080  Rescued from the lockers in which they were le...          2002.0
# 5081  This book is the story of a young girl obsesse...          1980.0
# 5086  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5087  This collection of the timeless teachings of o...          1999.0
# 5088  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 2               3.93      512.0        29532.0
# 8               4.03      522.0         2966.0
# 30              3.50       32.0            1.0
# 31              4.09      176.0         2245.0
# ...              ...        ...            ...
# 5080            3.75      393.0         5560.0
# 5081            3.22      218.0          134.0
# 5086            3.82      198.0         1568.0
# 5087            4.51      531.0          104.0
# 5088            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 2                                        Rage of angels
# 8                                   Warhost of Vastmark
# 30                                   Ocean Star Express
# 31    Tree and Leaf: The Homecoming of Beorhtnoth : ...
# ...                                                 ...
# 5080                                 Coin Locker Babies
# 5081                                   Cry, the Peacock
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# 5087     I Am that: Talks with Sri Nisargadatta Maharaj
# 5088                           The Berlin Phenomenology
#
#                                      tagged_description   simple_categories
# 0     9780002005883: A NOVEL THAT READERS and critic...             Fiction
# 2     9780006178736: A memorable, mesmerizing heroin...             Fiction
# 8     9780006482079: Tricked once more by his wily h...             Fiction
# 30    9780006646006: Joe and his parents are enjoyin...  Children's Fiction
# 31    9780007105045: "The two works 'On fairy-storie...             Fiction
# ...                                                 ...                 ...
# 5080  9784770028969: Rescued from the lockers in whi...             Fiction
# 5081  9788122200850: This book is the story of a you...             Fiction
# 5086  9788179921623: Wisdom to Create a Life of Pass...          Nonfiction
# 5087  9788185300535: This collection of the timeless...          Nonfiction
# 5088  9789027712059: Since the three volume edition ...          Nonfiction
#
# [4161 rows x 14 columns]

# %%
# La piattaforma HugginFace offre molti modelli open-source per fare zero-shot classification
# Un modello simile sarà anche utilizzato per fare sentiment analysis sulle descrizioni dei libri, per filtrarli in base al mood di lettura

# Pycharm ha una funzionalità che permette di scegliere da IDE direttamente il modello a cui fare riferimento
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"] # Label di classificazione

pipe = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# WARNING:tensorflow:From C:\Users\mazze\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu

# %%
# Primo esempio di libro Fiction
# Lo utilizzo per fare una prova sul modello appena caricato
books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]
pipe (sequence, fiction_categories)

# Verifichiamo che il modello predica correttamente la classe di appartenza di questo libro Fiction alla classe esatta
# Non è massimo il punteggio di confidence nella assegnazione, ma abbastanza alto per considerare questo modello come accettabile per fare predizione
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438268899917603, 0.15617306530475616]}

# %%
# Per estrarre la label risultante dalla predizione si prende l'indice all'interno della lista che con la maggiore probabilità
import numpy as np

max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
# Si riunisce tutto all'interno di una funzione per automatizzare il processo
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]

    return max_label

# %%
# Ora si può usare il modello per fare una zero-shot classification sulle descrizioni e assegnare la label più probabile tra Fiction e NonFiction
# Vogliamo vedere quanto il modello performi bene in questo compito, e lo faremo considerando 
# un insieme di esempi che daremo in pasto al modello, e dopo la predizione dovremo confrontarli
# con le label (fiction, nonfiction) esatte

# Questa libreria serve a monitorare il tempo rimasto al completamento delle operazioni
from tqdm import tqdm

actual_cats = []
predicted_cats = [] # Qui saranno salvati i risultati delle predizioni

# %%
# Prova di quanti libri con etichetta Fiction vengano accuratamente predetti
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i] # Seleziona solo le descrizioni
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
# Out:
# 100%|██████████| 300/300 [19:12<00:00,  3.84s/it]

# %%
# Prova sui libri NonFiction
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]
# Out:
# 100%|██████████| 300/300 [20:59<00:00,  4.20s/it]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_cats, "predicted_categories": predicted_cats})

# %%
# A colpo d'occhio sembra che la predizione sia accettabile
predictions_df
# Out:
#     actual_categories predicted_categories  correct_prediction
# 0             Fiction              Fiction                   1
# 1             Fiction              Fiction                   1
# 2             Fiction              Fiction                   1
# 3             Fiction           Nonfiction                   0
# 4             Fiction           Nonfiction                   0
# ..                ...                  ...                 ...
# 595        Nonfiction           Nonfiction                   1
# 596        Nonfiction           Nonfiction                   1
# 597        Nonfiction           Nonfiction                   1
# 598        Nonfiction           Nonfiction                   1
# 599        Nonfiction           Nonfiction                   1
#
# [600 rows x 3 columns]

# %%
# Creazione di una colonna che mostri la corrispondenza tra predizioni e label corrette
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)

# %%
# Si contano in percentuale il numero di predizioni corrette
predictions_df["correct_prediction"].sum() / len(predictions_df)

# Questa percentuale è accettabile per il modello zero-shot scelto
# Convinti di questo, si può utilizzare questo modello per predirre le classi mancanti per i libri
# Out:
# 0.7816666666666666

# %%
# Si selezionano, tramite identificatore "isbn13", i libri con valore nullo per la colonna "simple_categories"
isbns = []
predicted_cats = []

missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
# Prova per verificare se il numero di libri senza etichetta, sommato a quello dei libri già etichettati, corrisponde al dataset totale
books[~books["simple_categories"].isna()].shape[0] + missing_cats.shape[0]
# Out:
# 5089

# %%
# Si estrapolano le descrizioni corrispondenti ai libri con valore mancante

for i in tqdm(range(0, len(missing_cats))):
    sequence = missing_cats["description"][i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_cats["isbn13"][i]]
# Out:
# 100%|██████████| 928/928 [50:33<00:00,  3.27s/it]

# %%
# DataFrame costituito dai libri etichettati da reinserire nel dataset originale
missing_predicted_df = pd.DataFrame({"isbn13": isbns, "predicted_categories": predicted_cats})

# %%
# Si riempono i valori delle categorie nulle con quelle appena predette
# Si fa un left join su "isbn13", perchè il dataframe è un sottoinsieme del dataset iniziale
books = pd.merge(books, missing_predicted_df, on="isbn13", how="left")

# Quando il valore in "simple_categories" è mancante, viene sostituito con il valore corrispondente dalla colonna "predicted_categories" 
books["simple_categories"] = np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])

# %%
# Elimino la colonna di categorie predette ausiliari già sfruttata
books = books.drop(columns=["predicted_categories"])

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5084  9788172235222  8172235224
# 5085  9788173031014  8173031010
# 5086  9788179921623  817992162X
# 5087  9788185300535  8185300534
# 5088  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5084                                  Mistaken Identity
# 5085                                Journey to the East
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# 5087                                          I Am that
# 5088                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5084                              Nayantara Sahgal
# 5085                                 Hermann Hesse
# 5086                                  Robin Sharma
# 5087  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5088                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5084        Indic fiction (English)
# 5085              Adventure stories
# 5086               Health & Fitness
# 5087                     Philosophy
# 5088                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5084  http://books.google.com/books/content?id=q-tKP...
# 5085  http://books.google.com/books/content?id=rq6JP...
# 5086  http://books.google.com/books/content?id=c_7mf...
# 5087  http://books.google.com/books/content?id=Fv_JP...
# 5088  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5084  On A Train Journey Home To North India After L...          2003.0
# 5085  This book tells the tale of a man who goes on ...          2002.0
# 5086  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5087  This collection of the timeless teachings of o...          1999.0
# 5088  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5084            2.93      324.0            0.0
# 5085            3.70      175.0           24.0
# 5086            3.82      198.0         1568.0
# 5087            4.51      531.0          104.0
# 5088            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5084                                  Mistaken Identity
# 5085                                Journey to the East
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# 5087     I Am that: Talks with Sri Nisargadatta Maharaj
# 5088                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883: A NOVEL THAT READERS and critic...           Fiction
# 1     9780002261982: A new 'Christie for Christmas' ...           Fiction
# 2     9780006178736: A memorable, mesmerizing heroin...           Fiction
# 3     9780006280897: Lewis' work on the nature of lo...        Nonfiction
# 4     9780006280934: "In The Problem of Pain, C.S. L...        Nonfiction
# ...                                                 ...               ...
# 5084  9788172235222: On A Train Journey Home To Nort...           Fiction
# 5085  9788173031014: This book tells the tale of a m...        Nonfiction
# 5086  9788179921623: Wisdom to Create a Life of Pass...        Nonfiction
# 5087  9788185300535: This collection of the timeless...        Nonfiction
# 5088  9789027712059: Since the three volume edition ...        Nonfiction
#
# [5089 rows x 14 columns]

# %%
print(books["simple_categories"].info())
print(books["simple_categories"].isna().sum())
print(books["simple_categories"].describe())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5089 entries, 0 to 5088
# Series name: simple_categories
# Non-Null Count  Dtype
# --------------  -----
# 5089 non-null   object
# dtypes: object(1)
# memory usage: 39.9+ KB
# None
# 0
# count        5089
# unique          4
# top       Fiction
# freq         2735
# Name: simple_categories, dtype: object

# %%
# Classi di categorie definite
books["simple_categories"].value_counts()
# Out:
# simple_categories
# Fiction                  2735
# Nonfiction               1915
# Children's Fiction        383
# Children's Nonfiction      56
# Name: count, dtype: int64

# %%
# Teoricamente, il modello zero-shot potrebbe essere riutilizzato per definire altre generi
# Nella pratica, potrebbe essere difficile capirne anche l'accuratezza nel compito di assegnazione delle classi:
# - Non ci sono abbastanza esempi di nuove classi su cui allenare adeguatamente il modello  
# - Ci sono molte etichette assegnabili ma potrebbero essere troppo specifiche

# Es. classi assegnabili comuni
books[books["categories"].str.lower().isin([
    "romance",
    "science fiction",
    "scifi",
    "fantasy",
    "horror",
    "mystery",
    "thriller", 
    "comedy", 
    "crime", 
    "historical"
])]

# Sotto questi appellativi, vi sono solo 15 esempi, troppo poco
# Per ora quindi lasciamo che le uniche classi filtrabili per la lettura da utente siano quelle 4 sopra indicate
# Out:
#              isbn13      isbn10                                     title  \
# 24    9780006513087  0006513085                                   Gravity
# 471   9780099410355  0099410354                                   Traitor
# 474   9780099422341  0099422344                            Yeats is Dead!
# 487   9780099446729  0099446723                            Blackwood Farm
# 1396  9780340837955  0340837950                Stranger in a Strange Land
# 1400  9780345251220  0345251229                      Visions from Nowhere
# 2781  9780575075597  0575075597                                    Replay
# 2796  9780590254762  0590254766      The lion, the witch and the wardrobe
# 3213  9780739423851  0739423851                           Wizard's Castle
# 3214  9780739439708  0739439707                              Time Quartet
# 3482  9780760728505  076072850X              20,000 Leagues Under the Sea
# 4390  9781416502043  1416502041  The Voyage of the Jerle Shannara Trilogy
# 4877  9781841494081  1841494089            The Darkness that Comes Before
# 4936  9781857231359  185723135X                            Use of Weapons
# 4952  9781857989342  1857989341                       The Gods Themselves
#
#                       authors       categories  \
# 24             Tess Gerritsen  Science fiction
# 471   Matthew Woodring Stover  Science fiction
# 474           Joseph O'Connor           Comedy
# 487                 Anne Rice           Horror
# 1396       Robert A. Heinlein  Science fiction
# 1400            William Arrow  Science fiction
# 2781             Ken Grimwood          Fantasy
# 2796      Clive Staples Lewis          Fantasy
# 3213        Diana Wynne Jones          Fantasy
# 3214        Madeleine L'Engle  Science fiction
# 3482              Jules Verne  Science fiction
# 4390             Terry Brooks          Fantasy
# 4877          R. Scott Bakker          Fantasy
# 4936               Iain Banks  Science fiction
# 4952             Isaac Asimov  Science fiction
#
#                                               thumbnail  \
# 24    http://books.google.com/books/content?id=KI66c...
# 471   http://books.google.com/books/content?id=VbICO...
# 474   http://books.google.com/books/content?id=DrE3I...
# 487   http://books.google.com/books/content?id=cIn8T...
# 1396  http://books.google.com/books/content?id=ZQhiP...
# 1400                                                NaN
# 2781  http://books.google.com/books/content?id=9vmNP...
# 2796                                                NaN
# 3213  http://books.google.com/books/content?id=hB7hA...
# 3214                                                NaN
# 3482                                                NaN
# 4390  http://books.google.com/books/content?id=jqVsA...
# 4877  http://books.google.com/books/content?id=BG8qG...
# 4936                                                NaN
# 4952  http://books.google.com/books/content?id=8ClIP...
#
#                                             description  published_year  \
# 24    Emma Watson a research physician has been trai...          2004.0
# 471   From the depths of catastrophe, a glimmer of h...          2002.0
# 474   In aid of Amnesty International, this is a bri...          2002.0
# 487   Lestat Is Back, Saviour And Demon, Presiding O...          2003.0
# 1396  Epic, entertaining, Stranger in a Strange Land...          2005.0
# 1400  The first novel in the series, "Return to the ...          1976.0
# 2781  At forty-three Jeff Winston is tired of his lo...          2005.0
# 2796  Four English school children enter the magic l...          1995.0
# 3213  Howl's moving castle - Eldest of three sisters...          2002.0
# 3214  Blending magic with quantum physics, Madeleine...          2003.0
# 3482  Retells the adventures of a French professor a...          2002.0
# 4390  When the body of a half-drowned elf is found f...          2004.0
# 4877  A score of centuries has passed since the Firs...          2005.0
# 4936  The man known as Cheradenine Zakalwe was one o...          1992.0
# 4952  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#       average_rating  num_pages  ratings_count  \
# 24              4.04      342.0         8024.0
# 471             4.00      320.0         6765.0
# 474             3.39      298.0           34.0
# 487             3.86      774.0        26145.0
# 1396            3.92      672.0          563.0
# 1400            3.23      183.0           10.0
# 2781            4.16      272.0          412.0
# 2796            4.21      189.0          860.0
# 3213            4.44      376.0          439.0
# 3214            4.35      646.0          165.0
# 3482            3.88      394.0       135778.0
# 4390            4.26     1260.0           84.0
# 4877            3.79      638.0          317.0
# 4936            4.19      411.0        30779.0
# 4952            4.09      288.0        41304.0
#
#                                     title_and_subtitle  \
# 24                                             Gravity
# 471                                            Traitor
# 474   Yeats is Dead!: A Novel by Fifteen Irish Writers
# 487                                     Blackwood Farm
# 1396                        Stranger in a Strange Land
# 1400                              Visions from Nowhere
# 2781                                            Replay
# 2796              The lion, the witch and the wardrobe
# 3213                                   Wizard's Castle
# 3214                                      Time Quartet
# 3482                      20,000 Leagues Under the Sea
# 4390          The Voyage of the Jerle Shannara Trilogy
# 4877                    The Darkness that Comes Before
# 4936                                    Use of Weapons
# 4952                               The Gods Themselves
#
#                                      tagged_description simple_categories
# 24    9780006513087: Emma Watson a research physicia...        Nonfiction
# 471   9780099410355: From the depths of catastrophe,...           Fiction
# 474   9780099422341: In aid of Amnesty International...           Fiction
# 487   9780099446729: Lestat Is Back, Saviour And Dem...           Fiction
# 1396  9780340837955: Epic, entertaining, Stranger in...           Fiction
# 1400  9780345251220: The first novel in the series, ...           Fiction
# 2781  9780575075597: At forty-three Jeff Winston is ...           Fiction
# 2796  9780590254762: Four English school children en...        Nonfiction
# 3213  9780739423851: Howl's moving castle - Eldest o...           Fiction
# 3214  9780739439708: Blending magic with quantum phy...           Fiction
# 3482  9780760728505: Retells the adventures of a Fre...           Fiction
# 4390  9781416502043: When the body of a half-drowned...           Fiction
# 4877  9781841494081: A score of centuries has passed...        Nonfiction
# 4936  9781857231359: The man known as Cheradenine Za...        Nonfiction
# 4952  9781857989342: In the year 2100, mankind on Ea...           Fiction

# %%
# Si salva questa nuova versione del dataset, con correzione della feature "categories"
books.to_csv("books_with_categories.csv", index=False)
