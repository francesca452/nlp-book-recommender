# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# GUARDARE SE VIENE MOSTRATO IL TITOLO E SOTTOTITOLO NELLA DASHBOARD

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5084  9788172235222  8172235224
# 5085  9788173031014  8173031010
# 5086  9788179921623  817992162X
# 5087  9788185300535  8185300534
# 5088  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5084                                  Mistaken Identity
# 5085                                Journey to the East
# 5086  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
# Goodreads-books
# DATASET
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jealousleopard/goodreadsbooks")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\mazze\.cache\kagglehub\datasets\jealousleopard\goodreadsbooks\versions\2

# %%
other = pd.read_csv(f"{path}/books.csv", on_bad_lines="skip")

# %%
other
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %%
#np.sort(other["  num_pages"].unique())
print(other[other["  num_pages"].between(0, 10)][["title", "  num_pages"]])
# Out:
#                                                    title    num_pages
# 10     The Hitchhiker's Guide to the Galaxy (Hitchhik...            6
# 215                                    Lord of the Flies            6
# 306    The 5 Love Languages / The 5 Love Languages Jo...            0
# 324                           The Richest Man in Babylon            4
# 330    Purpose Driven Life - For Commuters: What on E...            5
# ...                                                  ...          ...
# 10969                                        Howards End            9
# 11004                    The Roald Dahl Audio Collection            4
# 11076                    Artemis Fowl (Artemis Fowl  #1)            6
# 11077  Treasury of American Tall Tales: Volume 1: Dav...            0
# 11080          The Subtle Knife (His Dark Materials  #2)            8
#
# [208 rows x 2 columns]

# %%
df = other[other["title"].isin(books["title"])]
df
# Out:
#        bookID                                 title  \
# 12         21  A Short History of Nearly Everything
# 13         22           Bill Bryson's African Diary
# 19         28             Notes from a Small Island
# 36         61                        The Changeling
# 37         63                        The Changeling
# ...       ...                                   ...
# 11056   45362           The Passion of Jesus Christ
# 11058   45378                          Wartime Lies
# 11098   45549                     Undaunted Courage
# 11117   45630                     Whores for Gloria
# 11119   45633           You Bright and Risen Angels
#
#                                    authors  average_rating        isbn  \
# 12                             Bill Bryson            4.21  076790818X
# 13                             Bill Bryson            3.44  0767915062
# 19                             Bill Bryson            3.91  0380727501
# ...

# %%
books[books["title"] == "A Short History of Nearly Everything"]
# Out:
#              isbn13      isbn10                                 title  \
# 3676  9780767908184  076790818X  A Short History of Nearly Everything
# 4276  9780965738408  096573840X  A Short History of Nearly Everything
#
#           authors categories  \
# 3676  Bill Bryson    Science
# 4276  Bill Bryson    Science
#
#                                               thumbnail  \
# 3676  http://books.google.com/books/content?id=YjAnf...
# 4276                                                NaN
#
#                                             description  published_year  \
# 3676  The author of A Walk in the Woods traces the B...          2004.0
# 4276  In this book Bill Bryson explores the most int...          2003.0
#
#       average_rating  num_pages  ...  \
# 3676             4.2      544.0  ...
# 4276             4.2      545.0  ...
#
#                                      title_and_subtitle  \
# 3676               A Short History of Nearly Everything
# ...

# %%
# Amazon Top 50 Bestselling Books 2009 - 2019
# DATASET
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sootersaalu/amazon-top-50-bestselling-books-2009-2019")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 14.5k/14.5k [00:00<00:00, 7.43MB/s]
# Extracting files...
# Path to dataset files: C:\Users\mazze\.cache\kagglehub\datasets\sootersaalu\amazon-top-50-bestselling-books-2009-2019\versions\1

# %%
other2 = pd.read_csv(f"{path}/bestsellers with categories.csv")

# %%
other2
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# E' interessante notare che in ques
other2["Genre"].info() # Nessun valore nullo
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 550 entries, 0 to 549
# Series name: Genre
# Non-Null Count  Dtype
# --------------  -----
# 550 non-null    object
# dtypes: object(1)
# memory usage: 4.4+ KB

# %%
authors_list = books["authors"]
other2.isin(authors_list).sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
# Best-selling-books
# DATASET
import kagglehub

# Download latest version
path = kagglehub.dataset_download("drahulsingh/best-selling-books")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.26k/6.26k [00:00<00:00, 3.21MB/s]
# Extracting files...
# Path to dataset files: C:\Users\mazze\.cache\kagglehub\datasets\drahulsingh\best-selling-books\versions\2

# %%
other3 = pd.read_csv(f"{path}/best-selling-books.csv")

# %%
other3
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                             And Then There Were None
# 4                       Dream of the Red Chamber (紅樓夢)
# ..                                                 ...
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 0               Charles Dickens           English             1859
# 1      Antoine de Saint-Exupéry            French             1943
# 2                 J. K. Rowling           English             1997
# ...

# %%
authors_list = books["authors"]
other3.isin(authors_list).sum()
# Out:
# Book                             0
# Author(s)                        0
# Original language                0
# First published                  0
# Approximate sales in millions    0
# Genre                            0
# dtype: int64

# %%
# GoodReads 100k books
# DATASET
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mdhamani/goodreads-books-100k")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 44.2M/44.2M [00:22<00:00, 2.02MB/s]
# Extracting files...
# Path to dataset files: C:\Users\mazze\.cache\kagglehub\datasets\mdhamani\goodreads-books-100k\versions\1

# %%
other4 = pd.read_csv(f"{path}/GoodReads_100k_books.csv")

# %%
import numpy as np
num_parts = 4

# Divide il dataset in parti uguali
dfs = np.array_split(other4, num_parts)

temp_storage = {f"part_{i+1}": part for i, part in enumerate(dfs)}
# Out:
# C:\Users\mazze\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
temp_storage["part_1"]
# Out:
#                                           author bookformat  \
# 0                           Laurence M. Hauptman  Hardcover
# 1               Charlotte Fiell,Emmanuelle Dirix  Paperback
# 2                                  Andy Anderson  Paperback
# 3                           Carlotta R. Anderson  Hardcover
# 4                                  Jean Leveille        NaN
# ...                                          ...        ...
# 24995                             Bertrice Small  Paperback
# 24996                         Patrick Colm Hogan  Hardcover
# 24997  Sudipta  Bardhan-Quallen,Geraldo ValÃ©rio  Hardcover
# 24998         Dan Ben-Amos,Lenn Schramm,Dov NÃ´y  Hardcover
# 24999               Octavio Paz,Eliot Weinberger  Paperback
#
#                                                     desc  \
# 0      Reveals that several hundred thousand Indians ...
# 1      Fashion Sourcebook - 1920s is the first book i...
# 2      The seminal history and analysis of the Hungar...
# ...

# %%
#temp_storage["part_1"]["author"].info() # no null
#temp_storage["part_1"]["img"].isna().sum() #647 non copertine
#temp_storage["part_1"]["desc"].info() # alcuni nulli
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 25000 entries, 0 to 24999
# Series name: desc
# Non-Null Count  Dtype
# --------------  -----
# 23515 non-null  object
# dtypes: object(1)
# memory usage: 195.4+ KB

# %%
#temp_storage["part_2"]["author"].info() # no null
#temp_storage["part_2"]["img"].isna().sum() #808 non copertine
#temp_storage["part_2"]["desc"].info() # alcuni nulli

# %%
#temp_storage["part_3"]["author"].info() # no null
#temp_storage["part_3"]["img"].isna().sum() #929 non copertine
#temp_storage["part_3"]["desc"].info() # alcuni nulli

# %%
#temp_storage["part_4"]["author"].info() # no null
#temp_storage["part_4"]["img"].isna().sum() #661 non copertine
#temp_storage["part_4"]["desc"].info() # alcuni nulli

# %%
authors_list = books["authors"]
other2.isin(authors_list).sum()

# %%
books[books["title"].isin(temp_storage["part_1"]["title"])]
# Out:
#              isbn13      isbn10  \
# 9     9780006483014  0006483011
# 24    9780006513087  0006513085
# 85    9780030547744  0030547741
# 103   9780060218058  0060218053
# 145   9780060554736  0060554738
# ...             ...         ...
# 4999  9781843534099  1843534096
# 5004  9781844130801  1844130800
# 5007  9781844164110  184416411X
# 5103  9781890208288  1890208280
# 5130  9781904633273  1904633277
#
#                                                   title  \
# 9                              The Once and Future King
# 24                                              Gravity
# 85                             Where the Red Fern Grows
# 103           The Last of the Really Great Whangdoodles
# 145                                            The Game
# ...                                                 ...
# 4999                                               Cuba
# 5004  The Fourth Crusade and the Sack of Constantinople
# 5007                                          Outlander
# ...

# %%
temp_storage["part_1"][temp_storage["part_1"]["title"] == "Little Women"]
# Out:
#                                 author bookformat  \
# 23973  Laurie Lawlor,Louisa May Alcott  Hardcover
#
#                                                     desc  \
# 23973  This version of the classic story of four sist...
#
#                               genre  \
# 23973  Fiction,Classics,Young Adult
#
#                                                      img        isbn  \
# 23973  https://i.gr-assets.com/images/S/compressed.ph...  1557042160
#
#          isbn13                                               link  pages  \
# 23973  9.78E+12  https://goodreads.com/book/show/1161542.Little...     96
#
#        rating  reviews         title  totalratings
# 23973    4.05       15  Little Women           165

# %%
temp_storage["part_1"][temp_storage["part_1"]["title"] == "Little Women"]["img"].values[0]
# Out:
# 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1181519813l/1161542._SX318_.jpg'

# %%
temp_storage["part_1"][temp_storage["part_1"]["title"] == "Little Women"]["desc"].values[0]
# Out:
# 'This version of the classic story of four sisters in nineteenth-century New England is based on the Columbia Pictures movie.'

# %%
books[books["title"] == "Little Women"]
# Out:
#              isbn13      isbn10         title            authors   categories  \
# 5130  9781904633273  1904633277  Little Women  Louisa May Alcott  Family life
#
#                                               thumbnail  \
# 5130  http://books.google.com/books/content?id=lH7BZ...
#
#                                             description  published_year  \
# 5130  Timeless in its evocation of idealised family ...          2004.0
#
#       average_rating  num_pages  ...  title_and_subtitle  \
# 5130            4.06      327.0  ...        Little Women
#
#                                      tagged_description simple_categories  \
# 5130  9781904633273: Timeless in its evocation of id...           Fiction
#
#          anger   disgust      fear       joy   neutral  sadness  surprise
# 5130  0.064134  0.104007  0.051363  0.931885  0.885922  0.11169  0.078766
#
# [1 rows x 21 columns]

# %%
books[books["title"] == "Little Women"]["thumbnail"].values[0]
# Out:
# 'http://books.google.com/books/content?id=lH7BZwiYplEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'

# %%
books[books["title"] == "Little Women"]["description"].values[0]
# Out:
# "Timeless in its evocation of idealised family life and robustly enduring, Little Women is recognised as one of the best-loved classic children's stories of all time. Originally written as a 'girls' story', its appeal transcends the boundaries of time and age, making it as popular with adults as it is with young readers. For this is a beguiling story of happiness and hope, of the joys of companionship, domestic harmony and infinite mother love, all seen through the life of the March family. But which of the four March sisters to love best? For every reader must have their favourite. Independent, tomboyish Jo; delicate, loving Beth; pretty, kind Meg, or precocious and beautiful Amy, the baby of the family? Little Women was an instant success when first published in 1868, and followed only a year later by the sequel, Little Wives."

# %%
books_without_author = books[books["authors"].isna()][["title", "isbn13", "authors"]]

# %%
books_without_author
# Out:
#                                                   title         isbn13 authors
# 734                               The Epic of Gilgamesh  9780141026282     NaN
# 809                                  A Year Down Yonder  9780142300701     NaN
# 1862                                          Atonement  9780385503952     NaN
# 1984  Eric Carle's Very Little Library: The very hun...  9780399226908     NaN
# 2053                                           Blow Fly  9780425198735     NaN
# 2361                                   Wizard and Glass  9780451194862     NaN
# 2376                                     The Gunslinger  9780451210845     NaN
# 2457                      The Drama of the Gifted Child  9780465016907     NaN
# 2549                                  Out of this World  9780515131093     NaN
# 3061  The Sibley Field Guide to Birds of Western Nor...  9780679451211     NaN
# 3244                       The Legend of the Poinsettia  9780698115675     NaN
# ...

# %%
authors_part_1 = temp_storage["part_1"][["title", "author", "isbn13"]]
authors_part_2 = temp_storage["part_2"][["title", "author", "isbn13"]]
authors_part_3 = temp_storage["part_3"][["title", "author", "isbn13"]]
authors_part_4 = temp_storage["part_4"][["title", "author", "isbn13"]]

authors_part_1.rename(columns={'author': 'authors'}, inplace=True)
authors_part_2.rename(columns={'author': 'authors'}, inplace=True)
authors_part_3.rename(columns={'author': 'authors'}, inplace=True)
authors_part_4.rename(columns={'author': 'authors'}, inplace=True)
# Out:
# C:\Users\mazze\AppData\Local\Temp\ipykernel_26260\1974000219.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   authors_part_1.rename(columns={'author': 'authors'}, inplace=True)
# C:\Users\mazze\AppData\Local\Temp\ipykernel_26260\1974000219.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   authors_part_2.rename(columns={'author': 'authors'}, inplace=True)
# C:\Users\mazze\AppData\Local\Temp\ipykernel_26260\1974000219.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
print(authors_part_1.shape, authors_part_2.shape, authors_part_3.shape, authors_part_4.shape, books_without_author.shape)
# Out:
# (25000, 3) (25000, 3) (25000, 3) (25000, 3) (32, 3)

# %%
print(authors_part_1[authors_part_1["title"] == "Any Woman's Blues"])
print(authors_part_2[authors_part_2["title"] == "Any Woman's Blues"])
print(authors_part_3[authors_part_3["title"] == "Any Woman's Blues"])
print(authors_part_4[authors_part_4["title"] == "Any Woman's Blues"])
# Out:
# Empty DataFrame
# Columns: [title, authors, isbn13]
# Index: []
# Empty DataFrame
# Columns: [title, authors, isbn13]
# Index: []
# Empty DataFrame
# Columns: [title, authors, isbn13]
# Index: []
# Empty DataFrame
# Columns: [title, authors, isbn13]
# Index: []

# %%
# Supponiamo che i tuoi dataset siano già letti in due DataFrame:
# books_without_author (con isbn13, author, title)
# authors_part_1 (con author, title)

# Step 1: Unisci i dataset in base alle colonne 'author' e 'title'
merged_df = pd.merge(books_without_author, authors_part_1, on=['authors', 'title'], how='left', suffixes=('_df1', '_df2'))
merged_df
# Step 2: Aggiorna il campo 'author' nel primo dataset con quello del secondo dataset
#merged_df['author_df1'] = merged_df['author_df2'].combine_first(merged_df['author_df1'])

# Step 3: Rimuovi le colonne extra, se necessario, per lasciare solo le informazioni necessarie
#final_df = merged_df[['isbn13', 'author_df1', 'title']]

# Ora 'final_df' conterrà l'autore aggiornato nel primo dataset
# Out:
#                                                 title     isbn13_df1 authors  \
# 0                               The Epic of Gilgamesh  9780141026282     NaN
# 1                                  A Year Down Yonder  9780142300701     NaN
# 2                                           Atonement  9780385503952     NaN
# 3   Eric Carle's Very Little Library: The very hun...  9780399226908     NaN
# 4                                            Blow Fly  9780425198735     NaN
# 5                                    Wizard and Glass  9780451194862     NaN
# 6                                      The Gunslinger  9780451210845     NaN
# 7                       The Drama of the Gifted Child  9780465016907     NaN
# 8                                   Out of this World  9780515131093     NaN
# 9   The Sibley Field Guide to Birds of Western Nor...  9780679451211     NaN
# 10                       The Legend of the Poinsettia  9780698115675     NaN
# ...

# %%
'''#--- 1. Lunghezza del Titolo (in termini di caratteri o parole)

books["title_length"] = books["title"].apply(len) #lunghezza del titolo in caratteri
books["title_word_count"] = books["title"].apply(lambda x: len(x.split())) #lunghezza del titolo in parole


#--- 2. Distribuzione delle parole più comuni
from collections import Counter
import re

# Tokenizza i titoli in parole (rimuovendo la punteggiatura)
words = ' '.join(books['title']).lower()
words = re.findall(r'\b\w+\b', words)
word_counts = Counter(words)

# Mostra le 10 parole più comuni
print(word_counts.most_common(10))


#--- 3. Verifica della presenza di parole chiave o pattern
keywords = ['love', 'adventure', 'mystery', 'history', 'guide']
for keyword in keywords:
    books[keyword + '_in_title'] = books['title'].str.contains(keyword, case=False, na=False)


#--- 4. Verifica della presenza di numeri
books["contains_number"] = books["title"].str.contains(r"\d", na=False)


#--- 5. Controllo di titoli duplicati
duplicate_titles = books[books.duplicated(subset="title", keep=False)]
print(duplicate_titles)


#--- 6. Titoli in maiuscolo/minuscolo
books["all_upper"] = books["title"].apply(lambda x: x.isupper())
books["all_lower"] = books["title"].apply(lambda x: x.islower())
books["title_case"] = books["title"].apply(lambda x: x.istitle())


#--- 7. Pattern di data o anno
df["year_in_title"] = books["title"].str.extract(r"(\d{4})", expand=False)


#--- 8. Diversità dei titoli
books["unique_word_count"] = books["title"].apply(lambda x: len(set(x.split())))


#--- 9. Anomalie nei titoli
df["has_special_characters"] = df["title"].str.contains(r"[^A-Za-z0-9 ]", na=False)


#--- 10. Analisi di lunghezza del titolo in base al genere o altro
genre_statistics = df.groupby("genre")["title_length"].describe()


#--- 11. Creare una visualizzazione dei titoli
plt.hist(books["title_length"], bins=30)
plt.title("Distribuzione della lunghezza dei titoli")
plt.xlabel("Lunghezza del titolo (caratteri)")
plt.ylabel("Frequenza")
plt.show()

word_counts = pd.DataFrame(word_counts.most_common(10), columns=["Word", "Count"])
sns.barplot(x="Count", y="Word", data=word_counts)
plt.title("Parole più comuni nei titoli")
plt.show()
'''
